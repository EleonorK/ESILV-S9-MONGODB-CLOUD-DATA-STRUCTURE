# %% [markdown]
# # Query Performance

# %%
from pymongo import MongoClient
import pandas as pd
import time

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client['animeDB']

# %%
collec = db.list_collection_names()
collec
# Out:
# ['studios_l',
#  'genres_l',
#  'anime_recommendation_table',
#  'demo_l',
#  'tm_ky',
#  'anime_table',
#  'rank_table',
#  'anime_ranking_table']

# %% [markdown]
# ## End-User Queries

# %% [markdown]
# ### Query 1

# %%
# Récupérer l'ID du genre "Adventure" et le convertir en chaîne de caractères
adventure_genre_id = db.genres_l.find_one({"genres_de": "Adventure"})['genres_id']
adventure_genre_id = str(adventure_genre_id)

# %%
def execute_and_print_query_1():
    results = db.anime_ranking_table.aggregate([
        {"$addFields": {"genres_id_array": {"$split": ["$genres_id", ","]}}},
        {"$match": {"genres_id_array": adventure_genre_id, "popularity": {"$gt": 500}}},
        {"$project": {"_id": 0, "title": 1, "popularity": 1, "genre": "Adventure"}}
    ])
    for result in results:
        print(result)
execute_and_print_query_1()
# Out:
# {'popularity': 1412, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 737, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 2382, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 527, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1577, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 3301, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 2541, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 1818, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 883, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1642, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 2229, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 2305, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 5475, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 2080, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 1558, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 509, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1023, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 2165, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 1524, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 4451, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 4499, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 1276, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 6430, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 3890, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 8298, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 1796, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 1102, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 4397, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 904, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 4817, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 5183, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 3850, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 8643, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 9660, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 1658, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 7544, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 7797, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 3079, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 4028, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 1495, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 538, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 9516, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 9591, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 1513, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 1778, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 10213, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 750, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 688, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 2612, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 1299, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 3809, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 1503, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 3896, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4092, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 2197, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 1317, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 4734, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 695, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 2324, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 1193, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1928, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 1535, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1055, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 1381, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 1614, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 3051, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 2203, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 5003, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 1571, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 635, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 3050, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 4178, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 1611, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 1388, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 1223, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 5409, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 748, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 6483, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 668, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 1337, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 1483, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 4478, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 3020, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 1069, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 1419, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 1587, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 3307, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 536, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 2548, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 2393, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 888, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1830, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 748, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 2315, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 1656, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 2235, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 5487, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 2094, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 1568, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 515, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 3908, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 1033, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 2175, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 4510, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 8310, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 1115, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1805, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 915, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 4416, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 4839, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 5196, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 1283, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 6452, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 1669, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 9675, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 4461, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 8669, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 7561, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1541, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 3870, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 7810, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 3090, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 4030, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 1510, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 543, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 9532, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 9611, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 1524, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 10223, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 687, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 758, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 1786, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 2607, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 1505, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 1301, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 3807, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 3889, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 2200, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 4088, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 1305, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 4730, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 694, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1184, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 2316, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 1930, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 1520, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1380, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 1057, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 3038, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 1573, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 2184, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1608, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 4954, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3031, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 4170, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 627, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 1593, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 5353, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 1374, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 1208, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 745, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 6407, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1330, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 3003, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 1495, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 4491, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 676, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 1083, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 1503, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 757, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 1207, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 679, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 3029, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 747, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 2315, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 629, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 537, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1058, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 1572, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1116, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 545, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1184, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1519, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1657, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 5489, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 1611, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 1587, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1667, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 1032, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1543, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 695, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1526, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 2552, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 689, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 2184, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1505, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 890, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1380, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 514, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1424, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3310, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 1836, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 751, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1090, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 2320, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 1303, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 1592, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 1807, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 2098, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 7553, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1511, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 1786, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 2395, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 3041, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 916, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 2178, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 1283, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 3093, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 4087, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 1576, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 2607, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 4417, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 6444, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 4512, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 3002, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 7807, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 4944, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3906, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 1304, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4736, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 4464, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 3889, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4838, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 5193, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 8324, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 3866, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1329, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2240, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 1933, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 2204, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 3809, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 5345, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 10235, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 9666, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 9618, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 9544, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 6399, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1373, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 8662, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 4501, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4022, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 4176, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 1509, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1210, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 756, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 681, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 3032, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 748, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 630, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 2315, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 539, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1114, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1061, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 545, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1577, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1183, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1661, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 1522, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1610, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 5500, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 1592, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 693, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1531, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 1031, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1672, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 1546, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 2556, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 690, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1502, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 893, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 2184, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1383, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 513, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1425, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3311, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 1842, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 2322, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 751, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1091, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 7550, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1298, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 1595, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 1815, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 2102, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 916, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 1512, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 2180, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 1790, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 2397, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 3044, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 1283, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 3098, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 4086, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 1580, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 2612, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 4425, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 4521, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 7817, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 6454, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 3010, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 3904, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 4942, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 5203, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 3890, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4472, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1305, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4737, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 4842, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 8339, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 3867, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1334, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2244, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 1937, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 2206, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 5361, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 9669, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 10245, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 9608, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 9538, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 3811, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 4021, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 4513, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4181, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 8679, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 6416, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1378, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 1460, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1212, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 769, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 673, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 3040, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 752, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 636, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 2323, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 544, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1592, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1070, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 549, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1130, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1670, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 1618, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 5530, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 698, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1542, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 1042, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1519, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1607, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1186, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1685, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 1562, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 2573, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 2196, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 697, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1517, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 902, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1392, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 517, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1432, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3318, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 1849, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 2339, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 763, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1023, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 7589, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1310, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 1597, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 1824, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 2118, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 927, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 1523, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 2198, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 3061, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 1801, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 2417, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 1300, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 4108, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 3113, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 1590, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 4448, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 2637, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 4545, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 7861, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 3016, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 6483, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 4921, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3923, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5229, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 3907, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4498, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1317, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4765, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 4868, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 8382, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 3889, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1344, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2263, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 1955, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 9637, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 2218, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 9568, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 3832, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 9709, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 5339, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 10280, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 6391, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1380, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 8722, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 4493, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4198, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4043, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 1458, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1212, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 769, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 3052, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 673, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 755, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 633, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 2328, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 547, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1131, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1594, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1078, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 549, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1191, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1521, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1624, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 1677, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 5540, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 1046, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1551, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 701, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1610, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1691, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 2199, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1571, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 2584, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 702, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1520, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 903, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1400, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 520, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1434, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3325, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 1861, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 765, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 2347, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 1019, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 1312, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 7598, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1835, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 2126, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 1599, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 933, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 1530, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 2203, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 1806, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 2428, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 3072, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 4115, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 3127, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 1595, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 1305, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 2645, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 6499, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 4559, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4464, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 3020, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 7876, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 4918, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3926, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5239, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 3921, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4511, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1327, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4778, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 3897, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1347, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2273, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 1960, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 4871, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 8396, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 9718, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 3839, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 5326, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 9661, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 9585, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 2225, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 4040, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 6362, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1383, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 8726, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 4504, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4209, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 10306, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 1449, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1204, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 779, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 3067, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 670, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 760, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 626, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 2340, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 1095, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 552, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 554, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1197, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1619, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1520, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1138, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1634, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 1698, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 5591, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 705, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1625, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1714, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 1594, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 1060, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1578, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 2611, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 2217, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 713, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1540, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 917, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 1414, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 526, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1448, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3353, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 1881, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 778, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1014, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 1311, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 7669, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1603, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 2366, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 2155, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 1862, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 942, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 3097, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 1829, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 1551, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 2228, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 2454, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 1319, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 4152, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 3168, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 1618, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 4604, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4503, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 2672, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 6559, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 3027, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 7947, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 4901, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3955, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5285, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 3959, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4550, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1342, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4819, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 1356, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2302, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 1980, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 9745, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 4906, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 8481, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 3933, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 9678, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 2249, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 9780, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 5299, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 3880, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 10414, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 1385, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 8808, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 4539, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4257, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4051, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 6347, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1444, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1206, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 778, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 3065, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 671, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 758, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 2340, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 625, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 502, 'title': 'Digimon Adventure', 'genre': 'Adventure'}
# {'popularity': 557, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1142, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1624, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 554, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1098, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 1522, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1200, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1064, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1628, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 706, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1720, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 1598, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 1581, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 1635, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 5605, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 1700, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 2613, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 2217, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1415, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 1542, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 525, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 917, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 716, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1450, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 1888, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 3363, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 2370, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 779, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1312, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 7664, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 1012, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 1600, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 2159, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 1868, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 1556, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 2231, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 3105, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# ...
# {'popularity': 1345, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 1656, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 4697, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4587, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 2716, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 4207, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 3244, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 3053, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 8057, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 4914, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 6675, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 3993, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5373, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 4639, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1381, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 4888, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 4009, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4982, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 1375, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 3995, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 8601, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 2021, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 2351, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 9896, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 9826, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 5289, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 9851, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 3939, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 2284, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 6305, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1393, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 8924, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 10595, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 4076, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 4607, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4349, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 1402, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1172, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 821, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 505, 'title': 'Cardcaptor Sakura', 'genre': 'Adventure'}
# {'popularity': 696, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 3190, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 775, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 2453, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 601, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 543, 'title': 'Digimon Adventure', 'genre': 'Adventure'}
# {'popularity': 612, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1217, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 581, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 1550, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 1760, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1192, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 1220, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1731, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 1812, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 1153, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 503, 'title': 'Pandora Hearts', 'genre': 'Adventure'}
# {'popularity': 1748, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1718, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 1846, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 5893, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 736, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1751, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 2314, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 1649, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 1008, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 2786, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 1524, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 763, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 560, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1544, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 1347, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 2015, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 3559, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 2529, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 846, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1686, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 7872, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 960, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 2299, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 2011, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 1037, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 1967, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 1685, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 3306, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 2379, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 2627, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 3430, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 1756, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 1415, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 4767, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 4882, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 4367, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 2839, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 8210, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 6881, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 4945, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3123, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 4137, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5564, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 4169, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4793, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 5046, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 1462, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 5145, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 4156, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1410, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 8843, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 2488, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 2120, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 5271, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 10033, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 2392, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 10217, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 4099, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 10140, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 4149, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 10940, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 6289, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 9177, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 1425, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 4757, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 4525, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 1406, 'title': 'Golden Kamuy 3rd Season', 'genre': 'Adventure'}
# {'popularity': 1165, 'title': 'Golden Kamuy 2nd Season', 'genre': 'Adventure'}
# {'popularity': 831, 'title': 'InuYasha: Kanketsu-hen', 'genre': 'Adventure'}
# {'popularity': 3215, 'title': 'Lupin III: Part 5', 'genre': 'Adventure'}
# {'popularity': 695, 'title': 'Eizouken ni wa Te wo Dasu na!', 'genre': 'Adventure'}
# {'popularity': 776, 'title': 'Kanata no Astra', 'genre': 'Adventure'}
# {'popularity': 508, 'title': 'Cardcaptor Sakura', 'genre': 'Adventure'}
# {'popularity': 2472, 'title': 'Lupin III (2015)', 'genre': 'Adventure'}
# {'popularity': 600, 'title': 'Golden Kamuy', 'genre': 'Adventure'}
# {'popularity': 548, 'title': 'Digimon Adventure', 'genre': 'Adventure'}
# {'popularity': 1231, 'title': 'Saint Seiya', 'genre': 'Adventure'}
# {'popularity': 1202, 'title': 'D.Gray-man Hallow', 'genre': 'Adventure'}
# {'popularity': 1228, 'title': 'Dragon Ball Kai (2014)', 'genre': 'Adventure'}
# {'popularity': 1782, 'title': 'Ueki no Housoku', 'genre': 'Adventure'}
# {'popularity': 1746, 'title': 'Cardcaptor Sakura: Clear Card-hen', 'genre': 'Adventure'}
# {'popularity': 616, 'title': 'Shaman King', 'genre': 'Adventure'}
# {'popularity': 1557, 'title': 'Pokemon XY&Z', 'genre': 'Adventure'}
# {'popularity': 583, 'title': 'Dragon Ball Kai', 'genre': 'Adventure'}
# {'popularity': 509, 'title': 'Pandora Hearts', 'genre': 'Adventure'}
# {'popularity': 1161, 'title': 'Digimon Tamers', 'genre': 'Adventure'}
# {'popularity': 1825, 'title': 'Kyou kara Maou!', 'genre': 'Adventure'}
# {'popularity': 1736, 'title': 'Tegamibachi', 'genre': 'Adventure'}
# {'popularity': 5942, 'title': 'Mahoujin Guruguru', 'genre': 'Adventure'}
# {'popularity': 1762, 'title': 'Fushigi Yuugi', 'genre': 'Adventure'}
# {'popularity': 1865, 'title': 'Kekkaishi (TV)', 'genre': 'Adventure'}
# {'popularity': 741, 'title': 'Soredemo Sekai wa Utsukushii', 'genre': 'Adventure'}
# {'popularity': 1771, 'title': 'Tsubasa Chronicle 2nd Season', 'genre': 'Adventure'}
# {'popularity': 2335, 'title': 'Shoukoku no Altair', 'genre': 'Adventure'}
# {'popularity': 2829, 'title': 'Gensoumaden Saiyuuki', 'genre': 'Adventure'}
# {'popularity': 1665, 'title': 'Toriko', 'genre': 'Adventure'}
# {'popularity': 1015, 'title': 'Tsubasa Chronicle', 'genre': 'Adventure'}
# {'popularity': 770, 'title': 'Densetsu no Yuusha no Densetsu', 'genre': 'Adventure'}
# {'popularity': 1541, 'title': 'Arslan Senki (TV): Fuujin Ranbu', 'genre': 'Adventure'}
# {'popularity': 564, 'title': 'Yu<U+2606>Gi<U+2606>Oh! Duel Monsters', 'genre': 'Adventure'}
# {'popularity': 1350, 'title': 'Pokemon XY', 'genre': 'Adventure'}
# {'popularity': 2040, 'title': 'Scrapped Princess', 'genre': 'Adventure'}
# {'popularity': 1561, 'title': 'Sunabouzu', 'genre': 'Adventure'}
# {'popularity': 3600, 'title': 'Saiyuuki Reload', 'genre': 'Adventure'}
# {'popularity': 7918, 'title': 'Tetsujin 28-gou (2004)', 'genre': 'Adventure'}
# {'popularity': 2555, 'title': 'Rekka no Honoo', 'genre': 'Adventure'}
# {'popularity': 855, 'title': 'Black Cat (TV)', 'genre': 'Adventure'}
# {'popularity': 1696, 'title': 'Piano no Mori (TV)', 'genre': 'Adventure'}
# {'popularity': 2327, 'title': 'Gun x Sword', 'genre': 'Adventure'}
# {'popularity': 2034, 'title': 'Erementar Gerad', 'genre': 'Adventure'}
# {'popularity': 1044, 'title': 'Digimon Adventure 02', 'genre': 'Adventure'}
# {'popularity': 954, 'title': 'Edens Zero', 'genre': 'Adventure'}
# {'popularity': 2405, 'title': 'Juu Ou Sei', 'genre': 'Adventure'}
# {'popularity': 2656, 'title': 'Ayashi no Ceres', 'genre': 'Adventure'}
# {'popularity': 1984, 'title': 'Uragiri wa Boku no Namae wo Shitteiru', 'genre': 'Adventure'}
# {'popularity': 3348, 'title': 'Saiyuuki Reload Blast', 'genre': 'Adventure'}
# {'popularity': 1699, 'title': 'Hakushaku to Yousei', 'genre': 'Adventure'}
# {'popularity': 1425, 'title': 'Digimon Frontier', 'genre': 'Adventure'}
# {'popularity': 4414, 'title': 'Cardfight!! Vanguard: Link Joker-hen', 'genre': 'Adventure'}
# {'popularity': 3477, 'title': 'Hatenkou Yuugi', 'genre': 'Adventure'}
# {'popularity': 4817, 'title': 'Yoroiden Samurai Troopers', 'genre': 'Adventure'}
# {'popularity': 1773, 'title': 'Alice to Zouroku', 'genre': 'Adventure'}
# {'popularity': 4934, 'title': 'Senkaiden Houshin Engi', 'genre': 'Adventure'}
# {'popularity': 8253, 'title': 'Ninja Senshi Tobikage', 'genre': 'Adventure'}
# {'popularity': 2872, 'title': 'Cardfight!! Vanguard', 'genre': 'Adventure'}
# {'popularity': 6931, 'title': 'Gakuen Senki Muryou', 'genre': 'Adventure'}
# {'popularity': 4967, 'title': 'Beyblade Burst God', 'genre': 'Adventure'}
# {'popularity': 3154, 'title': 'Kuutei Dragons', 'genre': 'Adventure'}
# {'popularity': 4174, 'title': 'Sakura Taisen', 'genre': 'Adventure'}
# {'popularity': 5613, 'title': 'Hyakujuu-Ou GoLion', 'genre': 'Adventure'}
# {'popularity': 4215, 'title': 'Cardfight!! Vanguard: Asia Circuit-hen', 'genre': 'Adventure'}
# {'popularity': 4841, 'title': 'Majutsushi Orphen: Revenge', 'genre': 'Adventure'}
# {'popularity': 1479, 'title': 'Brave 10', 'genre': 'Adventure'}
# {'popularity': 5087, 'title': 'Cardfight!! Vanguard: Legion Mate-hen', 'genre': 'Adventure'}
# {'popularity': 5194, 'title': 'Mach GoGoGo', 'genre': 'Adventure'}
# {'popularity': 8911, 'title': 'Project BLUE Chikyuu SOS', 'genre': 'Adventure'}
# {'popularity': 4208, 'title': 'Mamotte! Lollipop', 'genre': 'Adventure'}
# {'popularity': 1422, 'title': 'Sounan Desu ka?', 'genre': 'Adventure'}
# {'popularity': 2519, 'title': '.hack//Tasogare no Udewa Densetsu', 'genre': 'Adventure'}
# {'popularity': 10079, 'title': 'Uchuu Senshi Baldios', 'genre': 'Adventure'}
# {'popularity': 2147, 'title': 'Norn9: Norn+Nonet', 'genre': 'Adventure'}
# {'popularity': 10282, 'title': 'Kagaku Ninja-tai Gatchaman F', 'genre': 'Adventure'}
# {'popularity': 10203, 'title': 'Kagaku Ninja-tai Gatchaman II', 'genre': 'Adventure'}
# {'popularity': 2417, 'title': 'Arata Kangatari', 'genre': 'Adventure'}
# {'popularity': 4146, 'title': 'Digimon Xros Wars: Toki wo Kakeru Shounen Hunter-tachi', 'genre': 'Adventure'}
# {'popularity': 4185, 'title': 'Kodai Ouja Kyouryuu King', 'genre': 'Adventure'}
# {'popularity': 11013, 'title': 'Card Wang: Mix Master', 'genre': 'Adventure'}
# {'popularity': 5287, 'title': 'Beyblade Burst Chouzetsu', 'genre': 'Adventure'}
# {'popularity': 9232, 'title': 'Masou Kishin Cybuster', 'genre': 'Adventure'}
# {'popularity': 4806, 'title': 'Shin Sakura Taisen the Animation', 'genre': 'Adventure'}
# {'popularity': 6303, 'title': 'Beyblade Burst Gachi', 'genre': 'Adventure'}
# {'popularity': 1434, 'title': 'Gunjou no Magmell', 'genre': 'Adventure'}
# {'popularity': 4578, 'title': 'Hakyuu Houshin Engi', 'genre': 'Adventure'}

# %%
# Fonction pour exécuter la requête 1
def execute_query_1():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$addFields": {"genres_id_array": {"$split": ["$genres_id", ","]}}},
        {"$match": {"genres_id_array": adventure_genre_id, "popularity": {"$gt": 500}}},
        {"$project": {"_id": 0, "title": 1, "popularity": 1, "genre": "Adventure"}}
    ])
    return time.time() - start_time

# Mesurer les temps d'exécution pour la requête 1
execution_times_query_1 = []
for _ in range(10):
    execution_time = execute_query_1()
    execution_times_query_1.append(execution_time)

# Retirer le max et le min pour la requête 1
execution_times_query_1.remove(max(execution_times_query_1))
execution_times_query_1.remove(min(execution_times_query_1))

# Calculer la moyenne pour la requête 1
average_time_query_1 = sum(execution_times_query_1) / len(execution_times_query_1)
average_time_query_1 = round(average_time_query_1,3)
print(f"Average execution time for query 1: {average_time_query_1} seconds")
# Out:
# Average execution time for query 1: 0.006 seconds

# %% [markdown]
# ### Query 2

# %%
# Récupérer l'ID du studio "Madhouse"
madhouse_studio_id = db.studios_l.find_one({"studio_de": "Madhouse"})['studio_id']

# %%
def execute_and_print_query_2():
    results = db.anime_table.aggregate([
        {"$match": {"studio_id": madhouse_studio_id, "status": "finished_airing"}},
        {"$lookup": {
            "from": "studios_l",
            "localField": "studio_id",
            "foreignField": "studio_id",
            "as": "studio_info"}},
        {"$unwind": "$studio_info"},
        {"$group": {
            "_id": "$title",
            "studio": {"$first": "$studio_info.studio_de"}}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "studio": 1,
            "status": 1}}
    ])
    for result in results:
        print(result)

execute_and_print_query_2()
# Out:
# {'studio': 'Madhouse', 'title': 'Pita Ten'}
# {'studio': 'Madhouse', 'title': 'Needless'}
# {'studio': 'Madhouse', 'title': 'ACCA: 13-ku Kansatsu-ka'}
# {'studio': 'Madhouse', 'title': 'Shigurui'}
# {'studio': 'Madhouse', 'title': 'Btooom!'}
# {'studio': 'Madhouse', 'title': 'Highschool of the Dead'}
# {'studio': 'Madhouse', 'title': 'Nana'}
# {'studio': 'Madhouse', 'title': 'X'}
# {'studio': 'Madhouse', 'title': 'Hunter x Hunter (2011)'}
# {'studio': 'Madhouse', 'title': 'Saiunkoku Monogatari'}
# {'studio': 'Madhouse', 'title': 'No Guns Life'}
# {'studio': 'Madhouse', 'title': 'Claymore'}
# {'studio': 'Madhouse', 'title': 'Gungrave'}
# {'studio': 'Madhouse', 'title': 'Trigun'}
# {'studio': 'Madhouse', 'title': 'Black Lagoon'}
# {'studio': 'Madhouse', 'title': 'Chuukan Kanriroku Tonegawa'}
# {'studio': 'Madhouse', 'title': 'One Punch Man'}
# {'studio': 'Madhouse', 'title': 'Touhai Densetsu Akagi: Yami ni Maiorita Tensai'}
# {'studio': 'Madhouse', 'title': 'Beck'}
# {'studio': 'Madhouse', 'title': 'RideBack'}
# {'studio': 'Madhouse', 'title': 'Tenjou Tenge'}
# {'studio': 'Madhouse', 'title': 'Sakura Taisen'}
# {'studio': 'Madhouse', 'title': 'Cardcaptor Sakura: Clear Card-hen'}
# {'studio': 'Madhouse', 'title': 'Petshop of Horrors'}
# {'studio': 'Madhouse', 'title': 'Death Note'}
# {'studio': 'Madhouse', 'title': 'Gyakkyou Burai Kaiji: Hakairoku-hen'}
# {'studio': 'Madhouse', 'title': 'Chihayafuru'}
# {'studio': 'Madhouse', 'title': 'Gakuen Senki Muryou'}
# {'studio': 'Madhouse', 'title': 'Gyakkyou Burai Kaiji: Ultimate Survivor'}
# {'studio': 'Madhouse', 'title': 'Rainbow: Nisha Rokubou no Shichinin'}
# {'studio': 'Madhouse', 'title': 'No Guns Life 2nd Season'}
# {'studio': 'Madhouse', 'title': 'Prince of Stride: Alternative'}
# {'studio': 'Madhouse', 'title': 'Ore Monogatari!!'}
# {'studio': 'Madhouse', 'title': 'Cardcaptor Sakura'}
# {'studio': 'Madhouse', 'title': 'Kyuuketsuki Sugu Shinu'}
# {'studio': 'Madhouse', 'title': 'Hajime no Ippo'}
# {'studio': 'Madhouse', 'title': "Chi's Sweet Home: Atarashii Ouchi"}
# {'studio': 'Madhouse', 'title': 'Black Lagoon: The Second Barrage'}
# {'studio': 'Madhouse', 'title': 'Kiseijuu: Sei no Kakuritsu'}
# {'studio': 'Madhouse', 'title': 'Chobits'}
# {'studio': 'Madhouse', 'title': 'Kaibutsu Oujo'}
# {'studio': 'Madhouse', 'title': 'Hakozume: Kouban Joshi no Gyakushuu'}

# %%
def execute_query_2():
    start_time = time.time()
    db.anime_table.aggregate([
        {"$match": {"studio_id": madhouse_studio_id, "status": "finished_airing"}},
        {"$lookup": {
            "from": "studios_l",
            "localField": "studio_id",
            "foreignField": "studio_id",
            "as": "studio_info"}},
        {"$unwind": "$studio_info"},
        {"$group": {
            "_id": "$title",
            "studio": {"$first": "$studio_info.studio_de"}}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "studio": 1,
            "status": 1}}
    ])
    return time.time() - start_time

# Mesurer les temps d'exécution pour la requête 2
execution_times_query_2 = []
for _ in range(10):
    execution_time = execute_query_2()
    execution_times_query_2.append(execution_time)

# Retirer le max et le min pour la requête 2
execution_times_query_2.remove(max(execution_times_query_2))
execution_times_query_2.remove(min(execution_times_query_2))

# Calculer la moyenne pour la requête 2
average_time_query_2 = sum(execution_times_query_2) / len(execution_times_query_2)
average_time_query_2 = round(average_time_query_2, 2)
print(f"Average execution time for query 2: {average_time_query_2} seconds")
# Out:
# Average execution time for query 2: 0.52 seconds

# %% [markdown]
# ### Query 3

# %%
def execute_and_print_query_3():
    results = db.anime_ranking_table.aggregate([
        {"$match": {
            "$or": [
                {"title": "Yakitate!! Japan"},
                {"title": "Haikyuu!!"},
                {"title": "Gakuen Alice"},
                {"title": "Magi: The Kingdom of Magic"}
            ]}},
        {"$group": {
            "_id": "$title",
            "rank": {"$first": "$rank"},
            "popularity": {"$first": "$popularity"}}},
        {"$sort": {"rank": 1}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "rank": 1,
            "popularity": 1}}
    ])
    for result in results:
        print(result)
execute_and_print_query_3()
# Out:
# {'rank': 131.0, 'popularity': 38, 'title': 'Haikyuu!!'}
# {'rank': 278.0, 'popularity': 178, 'title': 'Magi: The Kingdom of Magic'}
# {'rank': 649.0, 'popularity': 1816, 'title': 'Yakitate!! Japan'}
# {'rank': 1213.0, 'popularity': 1787, 'title': 'Gakuen Alice'}

# %%
def execute_query_3():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$match": {
            "$or": [
                {"title": "Yakitate!! Japan"},
                {"title": "Haikyuu!!"},
                {"title": "Gakuen Alice"},
                {"title": "Magi: The Kingdom of Magic"}
            ]}},
        {"$group": {
            "_id": "$title",
            "rank": {"$first": "$rank"},
            "popularity": {"$first": "$popularity"}}},
        {"$sort": {"rank": 1}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "rank": 1,
            "popularity": 1}}
    ])
    return time.time() - start_time

# Mesurer les temps d'exécution pour la requête 3
execution_times_query_3 = []
for _ in range(10):
    execution_time = execute_query_3()
    execution_times_query_3.append(execution_time)

# Retirer le max et le min pour la requête 3
execution_times_query_3.remove(max(execution_times_query_3))
execution_times_query_3.remove(min(execution_times_query_3))

# Calculer la moyenne pour la requête 3
average_time_query_3 = sum(execution_times_query_3) / len(execution_times_query_3)
average_time_query_3 = round(average_time_query_3, 3)
print(f"Average execution time for query 3: {average_time_query_3} seconds")
# Out:
# Average execution time for query 3: 0.006 seconds

# %% [markdown]
# ### Query 4

# %%
def execute_and_print_query_4():
    results = db.anime_ranking_table.aggregate([
        {"$match": {"title": "Trigun"}},
        {"$lookup": {
            "from": "demo_l",
            "localField": "demo_id",
            "foreignField": "demo_id",
            "as": "demo_data"}},
        {"$unwind": {
            "path": "$demo_data",
            "preserveNullAndEmptyArrays": True}},
        {"$group": {
            "_id": "$title",
            "demo_de": {"$first": "$demo_data.demo_de"}}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "demo_de": {"$ifNull": ["$demo_de", "No demographic data"]}}}
    ])
    for result in results:
        print(result)
execute_and_print_query_4()
# Out:
# {'title': 'Trigun', 'demo_de': 'Shounen'}

# %%
def execute_query_4():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$match": {"title": "Trigun"}},
        {"$lookup": {
            "from": "demo_l",
            "localField": "demo_id",
            "foreignField": "demo_id",
            "as": "demo_data"}},
        {"$unwind": {
            "path": "$demo_data",
            "preserveNullAndEmptyArrays": True}},
        {"$group": {
            "_id": "$title",
            "demo_de": {"$first": "$demo_data.demo_de"}}},
        {"$project": {
            "_id": 0,
            "title": "$_id",
            "demo_de": {"$ifNull": ["$demo_de", "No demographic data"]}}}
    ])
    return time.time() - start_time

# Mesurer les temps d'exécution pour la requête 4
execution_times_query_4 = []
for _ in range(10):
    execution_time = execute_query_4()
    execution_times_query_4.append(execution_time)

# Retirer le max et le min pour la requête 4
execution_times_query_4.remove(max(execution_times_query_4))
execution_times_query_4.remove(min(execution_times_query_4))

# Calculer la moyenne pour la requête 1
average_time_query_4 = sum(execution_times_query_4) / len(execution_times_query_4)
average_time_query_4 = round(average_time_query_4, 3)
print(f"Average execution time for query 4: {average_time_query_4} seconds")
# Out:
# Average execution time for query 4: 0.005 seconds

# %% [markdown]
# ## Data Analysis Queries

# %% [markdown]
# ### Query 5

# %%
def execute_and_print_query_5():
    results = db.anime_ranking_table.aggregate([
        {"$lookup": {
            "from": "demo_l",
            "localField": "demo_id",
            "foreignField": "demo_id",
            "as": "demo_data"}},
        {"$unwind": "$demo_data"},
        {"$group": {
            "_id": "$demo_data.demo_de",
            "averagePopularity": {"$avg": "$popularity"}}},
        {"$project": {
            "_id": 0,
            "Type": "$_id",
            "Average_Popularity": {"$round": ["$averagePopularity", 2]}}},
        {"$sort": {"averagePopularity": -1}}
    ])
    for result in results:
        print(result)
execute_and_print_query_5()
# Out:
# {'Type': 'Shounen', 'Average_Popularity': 1625.98}
# {'Type': 'Seinen', 'Average_Popularity': 1601.88}
# {'Type': 'Kids', 'Average_Popularity': 4514.74}
# {'Type': 'Josei', 'Average_Popularity': 1917.42}
# {'Type': 'Shoujo', 'Average_Popularity': 1752.13}

# %%
# Query 5 Execution Function
def execute_query_5():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$lookup": {
            "from": "demo_l",
            "localField": "demo_id",
            "foreignField": "demo_id",
            "as": "demo_data"}},
        {"$unwind": "$demo_data"},
        {"$group": {
            "_id": "$demo_data.demo_de",
            "averagePopularity": {"$avg": "$popularity"}}},
        {"$project": {
            "_id": 0,
            "Type": "$_id",
            "Average_Popularity": {"$round": ["$averagePopularity", 2]}}},
        {"$sort": {"averagePopularity": -1}}
    ])
    return time.time() - start_time

# Mesurer les temps d'exécution pour la requête 5
execution_times_query_5 = []
for _ in range(10):
    execution_time = execute_query_5()
    execution_times_query_5.append(execution_time)

# Retirer le max et le min pour la requête 5
execution_times_query_5.remove(max(execution_times_query_5))
execution_times_query_5.remove(min(execution_times_query_5))

# Calculer la moyenne pour la requête 5
average_time_query_5 = sum(execution_times_query_5) / len(execution_times_query_5)
average_time_query_5 = round(average_time_query_5, 2)
print(f"Average execution time for query 5: {average_time_query_5} seconds")
# Out:
# Average execution time for query 5: 0.24 seconds

# %% [markdown]
# ### Query 6

# %%
def execute_and_print_query_6():
    results = db.anime_ranking_table.aggregate([
        {"$group": {
            "_id": "$studio_id",
            "averageRank": {"$avg": "$rank"}}},
        {"$sort": {"averageRank": 1}},
        {"$limit": 5},
        {"$lookup": {
            "from": "studios_l",
            "localField": "_id",
            "foreignField": "studio_id",
            "as": "studio_info"}},
        {"$unwind": "$studio_info"},
        {"$group": {
            "_id": "$studio_info.studio_de",
            "averageRank": {"$first": "$averageRank"}}},
        {"$sort": {"averageRank": 1}},
        {"$project": {
            "_id": 0,
            "studio": "$_id",
            "averageRank": {"$round": ["$averageRank", 2]}}}
    ])
    for result in results:
        print(result)
execute_and_print_query_6()
# Out:
# {'studio': 'Shuka', 'averageRank': 74.77}
# {'studio': 'ufotable', 'averageRank': 96.23}
# {'studio': 'Kyoto Animation', 'averageRank': 131.31}
# {'studio': 'Orange', 'averageRank': 166.23}
# {'studio': 'CloverWorks', 'averageRank': 207.81}

# %%
# Query 6 Execution Function
def execute_query_6():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$group": {
            "_id": "$studio_id",
            "averageRank": {"$avg": "$rank"}}},
        {"$sort": {"averageRank": 1}},
        {"$limit": 5},
        {"$lookup": {
            "from": "studios_l",
            "localField": "_id",
            "foreignField": "studio_id",
            "as": "studio_info"}},
        {"$unwind": "$studio_info"},
        {"$group": {
            "_id": "$studio_info.studio_de",
            "averageRank": {"$first": "$averageRank"}}},
        {"$sort": {"averageRank": 1}},
        {"$project": {
            "_id": 0,
            "studio": "$_id",
            "averageRank": {"$round": ["$averageRank", 2]}}}
    ])
    return time.time() - start_time

# Measure the execution times for query 6
execution_times_query_6 = []
for _ in range(10):
    execution_time = execute_query_6()
    execution_times_query_6.append(execution_time)

# Remove the maximum and minimum values for query 6
execution_times_query_6.remove(max(execution_times_query_6))
execution_times_query_6.remove(min(execution_times_query_6))

# Calculate the average for query 6
average_time_query_6 = sum(execution_times_query_6) / len(execution_times_query_6)
average_time_query_6 = round(average_time_query_6, 2)
print(f"Average execution time for query 6: {average_time_query_6} seconds")
# Out:
# Average execution time for query 6: 0.01 seconds

# %% [markdown]
# ### Query 7

# %%
def execute_and_print_query_7():
    results = db.anime_ranking_table.aggregate([
        {"$lookup": {
            "from": "anime_table",
            "localField": "mal_id",
            "foreignField": "mal_id",
            "as": "anime_details"}},
        {"$unwind": "$anime_details"},
        {"$group": {
            "_id": {
                "year": "$anime_details.start_season.year",
                "season": "$anime_details.start_season.season"},
            "average_popularity": {"$avg": "$popularity"}}},
        {"$project": {
            "_id": 0,
            "year": "$_id.year",
            "season": "$_id.season",
            "average_popularity": {"$round": ["$average_popularity", 2]}}},
        {"$sort": {"year": 1, "season": 1}}
    ])
    for result in results:
        print(result)
execute_and_print_query_7()
# Out:
# {'year': 1967.0, 'season': 'spring', 'average_popularity': 6349.42}
# {'year': 1978.0, 'season': 'fall', 'average_popularity': 9719.92}
# {'year': 1979.0, 'season': 'fall', 'average_popularity': 9791.23}
# {'year': 1980.0, 'season': 'summer', 'average_popularity': 9789.85}
# {'year': 1981.0, 'season': 'fall', 'average_popularity': 5696.92}
# {'year': 1981.0, 'season': 'spring', 'average_popularity': 5311.0}
# {'year': 1984.0, 'season': 'fall', 'average_popularity': 1537.31}
# {'year': 1985.0, 'season': 'fall', 'average_popularity': 7956.08}
# {'year': 1986.0, 'season': 'fall', 'average_popularity': 1148.38}
# {'year': 1986.0, 'season': 'winter', 'average_popularity': 139.46}
# {'year': 1988.0, 'season': 'spring', 'average_popularity': 4526.92}
# {'year': 1989.0, 'season': 'spring', 'average_popularity': 102.15}
# {'year': 1990.0, 'season': 'winter', 'average_popularity': 5175.92}
# {'year': 1992.0, 'season': 'fall', 'average_popularity': 280.92}
# {'year': 1992.0, 'season': 'spring', 'average_popularity': 556.85}
# {'year': 1993.0, 'season': 'fall', 'average_popularity': 773.62}
# {'year': 1994.0, 'season': 'fall', 'average_popularity': 5617.46}
# {'year': 1994.0, 'season': 'spring', 'average_popularity': 2670.38}
# {'year': 1995.0, 'season': 'spring', 'average_popularity': 1636.92}
# {'year': 1996.0, 'season': 'fall', 'average_popularity': 3162.23}
# {'year': 1996.0, 'season': 'spring', 'average_popularity': 2419.62}
# {'year': 1996.0, 'season': 'winter', 'average_popularity': 310.08}
# {'year': 1997.0, 'season': 'spring', 'average_popularity': 3780.59}
# {'year': 1997.0, 'season': 'summer', 'average_popularity': 2381.38}
# {'year': 1998.0, 'season': 'spring', 'average_popularity': 355.04}
# {'year': 1999.0, 'season': 'fall', 'average_popularity': 1830.25}
# {'year': 1999.0, 'season': 'spring', 'average_popularity': 4320.8}
# {'year': 1999.0, 'season': 'summer', 'average_popularity': 4631.46}
# {'year': 1999.0, 'season': 'winter', 'average_popularity': 2409.23}
# {'year': 2000.0, 'season': 'fall', 'average_popularity': 1018.89}
# {'year': 2000.0, 'season': 'spring', 'average_popularity': 1835.04}
# {'year': 2001.0, 'season': 'fall', 'average_popularity': 962.56}
# {'year': 2001.0, 'season': 'spring', 'average_popularity': 4029.79}
# {'year': 2001.0, 'season': 'summer', 'average_popularity': 459.65}
# {'year': 2002.0, 'season': 'fall', 'average_popularity': 1190.12}
# {'year': 2002.0, 'season': 'spring', 'average_popularity': 1894.34}
# {'year': 2003.0, 'season': 'fall', 'average_popularity': 1730.89}
# {'year': 2003.0, 'season': 'spring', 'average_popularity': 2747.1}
# {'year': 2003.0, 'season': 'winter', 'average_popularity': 3422.1}
# {'year': 2004.0, 'season': 'fall', 'average_popularity': 1298.36}
# {'year': 2004.0, 'season': 'spring', 'average_popularity': 2751.38}
# {'year': 2004.0, 'season': 'summer', 'average_popularity': 3807.0}
# {'year': 2004.0, 'season': 'winter', 'average_popularity': 2629.81}
# {'year': 2005.0, 'season': 'fall', 'average_popularity': 2321.44}
# {'year': 2005.0, 'season': 'spring', 'average_popularity': 1571.48}
# {'year': 2005.0, 'season': 'summer', 'average_popularity': 1880.07}
# {'year': 2005.0, 'season': 'winter', 'average_popularity': 1624.81}
# {'year': 2006.0, 'season': 'fall', 'average_popularity': 1385.99}
# {'year': 2006.0, 'season': 'spring', 'average_popularity': 1289.99}
# {'year': 2006.0, 'season': 'summer', 'average_popularity': 5440.32}
# {'year': 2007.0, 'season': 'fall', 'average_popularity': 2643.11}
# {'year': 2007.0, 'season': 'spring', 'average_popularity': 1305.69}
# {'year': 2007.0, 'season': 'summer', 'average_popularity': 1410.15}
# {'year': 2007.0, 'season': 'winter', 'average_popularity': 2307.27}
# {'year': 2008.0, 'season': 'fall', 'average_popularity': 822.79}
# {'year': 2008.0, 'season': 'spring', 'average_popularity': 1115.53}
# {'year': 2008.0, 'season': 'summer', 'average_popularity': 1818.52}
# {'year': 2008.0, 'season': 'winter', 'average_popularity': 3195.08}
# {'year': 2009.0, 'season': 'fall', 'average_popularity': 736.71}
# {'year': 2009.0, 'season': 'spring', 'average_popularity': 1405.04}
# {'year': 2009.0, 'season': 'summer', 'average_popularity': 2092.51}
# {'year': 2009.0, 'season': 'winter', 'average_popularity': 2466.79}
# {'year': 2010.0, 'season': 'fall', 'average_popularity': 1067.41}
# {'year': 2010.0, 'season': 'spring', 'average_popularity': 1105.36}
# {'year': 2010.0, 'season': 'summer', 'average_popularity': 612.03}
# {'year': 2010.0, 'season': 'winter', 'average_popularity': 1317.77}
# {'year': 2011.0, 'season': 'fall', 'average_popularity': 1273.71}
# {'year': 2011.0, 'season': 'spring', 'average_popularity': 784.82}
# {'year': 2011.0, 'season': 'summer', 'average_popularity': 1766.92}
# {'year': 2011.0, 'season': 'winter', 'average_popularity': 1409.45}
# {'year': 2012.0, 'season': 'fall', 'average_popularity': 685.87}
# {'year': 2012.0, 'season': 'spring', 'average_popularity': 1918.85}
# {'year': 2012.0, 'season': 'summer', 'average_popularity': 1270.51}
# {'year': 2012.0, 'season': 'winter', 'average_popularity': 2306.45}
# {'year': 2013.0, 'season': 'fall', 'average_popularity': 1126.89}
# {'year': 2013.0, 'season': 'spring', 'average_popularity': 1757.41}
# {'year': 2013.0, 'season': 'summer', 'average_popularity': 1440.84}
# {'year': 2013.0, 'season': 'winter', 'average_popularity': 3177.95}
# {'year': 2014.0, 'season': 'fall', 'average_popularity': 935.74}
# {'year': 2014.0, 'season': 'spring', 'average_popularity': 1348.59}
# {'year': 2014.0, 'season': 'summer', 'average_popularity': 1269.52}
# {'year': 2014.0, 'season': 'winter', 'average_popularity': 1113.47}
# {'year': 2015.0, 'season': 'fall', 'average_popularity': 1248.13}
# {'year': 2015.0, 'season': 'spring', 'average_popularity': 1039.67}
# {'year': 2015.0, 'season': 'summer', 'average_popularity': 929.35}
# {'year': 2015.0, 'season': 'winter', 'average_popularity': 813.86}
# {'year': 2016.0, 'season': 'fall', 'average_popularity': 2124.29}
# {'year': 2016.0, 'season': 'spring', 'average_popularity': 2232.85}
# {'year': 2016.0, 'season': 'summer', 'average_popularity': 1129.74}
# {'year': 2016.0, 'season': 'winter', 'average_popularity': 550.6}
# {'year': 2017.0, 'season': 'fall', 'average_popularity': 976.72}
# {'year': 2017.0, 'season': 'spring', 'average_popularity': 3880.44}
# {'year': 2017.0, 'season': 'summer', 'average_popularity': 1391.11}
# {'year': 2017.0, 'season': 'winter', 'average_popularity': 964.4}
# {'year': 2018.0, 'season': 'fall', 'average_popularity': 1973.48}
# {'year': 2018.0, 'season': 'spring', 'average_popularity': 2325.82}
# {'year': 2018.0, 'season': 'summer', 'average_popularity': 1446.97}
# {'year': 2018.0, 'season': 'winter', 'average_popularity': 1620.32}
# {'year': 2019.0, 'season': 'fall', 'average_popularity': 1170.27}
# {'year': 2019.0, 'season': 'spring', 'average_popularity': 1933.54}
# {'year': 2019.0, 'season': 'summer', 'average_popularity': 756.63}
# {'year': 2019.0, 'season': 'winter', 'average_popularity': 813.29}
# {'year': 2020.0, 'season': 'fall', 'average_popularity': 851.49}
# {'year': 2020.0, 'season': 'spring', 'average_popularity': 1943.29}
# {'year': 2020.0, 'season': 'summer', 'average_popularity': 1660.04}
# {'year': 2020.0, 'season': 'winter', 'average_popularity': 1991.23}
# {'year': 2021.0, 'season': 'fall', 'average_popularity': 2317.38}
# {'year': 2021.0, 'season': 'spring', 'average_popularity': 1229.02}
# {'year': 2021.0, 'season': 'summer', 'average_popularity': 1135.98}
# {'year': 2021.0, 'season': 'winter', 'average_popularity': 2035.73}

# %%
def execute_query_7():
    start_time = time.time()
    db.anime_ranking_table.aggregate([
        {"$lookup": {
            "from": "anime_table",
            "localField": "mal_id",
            "foreignField": "mal_id",
            "as": "anime_details"}},
        {"$unwind": "$anime_details"},
        {"$group": {
            "_id": {
                "year": "$anime_details.start_season.year",
                "season": "$anime_details.start_season.season"},
            "average_popularity": {"$avg": "$popularity"}}},
        {"$project": {
            "_id": 0,
            "year": "$_id.year",
            "season": "$_id.season",
            "average_popularity": {"$round": ["$average_popularity", 2]}}},
        {"$sort": {"year": 1, "season": 1}}
    ])
    return time.time() - start_time

# Measure the execution times for query 7
execution_times_query_7 = []
for _ in range(10):
    execution_time = execute_query_7()
    execution_times_query_7.append(execution_time)

# Remove the maximum and minimum values for query 7
execution_times_query_7.remove(max(execution_times_query_7))
execution_times_query_7.remove(min(execution_times_query_7))

# Calculate the average for query 7
average_time_query_7 = sum(execution_times_query_7) / len(execution_times_query_7)
average_time_query_7 = round(average_time_query_7, 2)
print(f"Average execution time for query 7: {average_time_query_7} seconds")
# Out:
# Average execution time for query 7: 11.4 seconds

# %% [markdown]
# ### Query 8

# %%
def execute_and_print_query_8():
    results = db.anime_table.aggregate([
        {"$lookup": {
            "from": "genres_l",
            "localField": "genres_id",
            "foreignField": "genres_id",
            "as": "genres_data"}},
        {"$unwind": "$genres_data"},
        {"$lookup": {
            "from": "anime_ranking_table",
            "localField": "mal_id",
            "foreignField": "mal_id",
            "as": "ranking_data"}},
        {"$unwind": "$ranking_data"},
        {"$group": {
            "_id": "$genres_data.genres_de",
            "episodesCompletedPerUser": {
                "$avg": {
                    "$multiply": [
                        {"$divide": ["$ranking_data.statistics_completed", "$ranking_data.statistics_num_scoring_users"]},
                        100
                    ]
                }
            },
            "episodesDroppedPerUser": {
                "$avg": {
                    "$multiply": [
                        {"$divide": ["$ranking_data.statistics_dropped", "$ranking_data.statistics_num_scoring_users"]},
                        100
                    ]
                }
            }
        }},
        {"$project": {
            "_id": 0,
            "genre": "$_id",
            "episodesCompletedPerUser": {"$concat": [{"$toString": {"$round": ["$episodesCompletedPerUser", 2]}}, "%"]},
            "episodesDroppedPerUser": {"$concat": [{"$toString": {"$round": ["$episodesDroppedPerUser", 2]}}, "%"]}
        }}
    ])
    for result in results:
        print(result)
execute_and_print_query_8()
# Out:
# {'genre': 'Action', 'episodesCompletedPerUser': '59.44%', 'episodesDroppedPerUser': '5.01%'}
# {'genre': 'Martial Arts', 'episodesCompletedPerUser': '64.99%', 'episodesDroppedPerUser': '8.21%'}
# {'genre': 'Mecha', 'episodesCompletedPerUser': '39.46%', 'episodesDroppedPerUser': '7.72%'}
# {'genre': 'Sports', 'episodesCompletedPerUser': '52.81%', 'episodesDroppedPerUser': '7.41%'}
# {'genre': 'Slice of Life', 'episodesCompletedPerUser': '47.48%', 'episodesDroppedPerUser': '5.29%'}
# {'genre': 'Mystery', 'episodesCompletedPerUser': '54.6%', 'episodesDroppedPerUser': '5.1%'}
# {'genre': 'Cars', 'episodesCompletedPerUser': '46.07%', 'episodesDroppedPerUser': '9.36%'}
# {'genre': 'Sci-Fi', 'episodesCompletedPerUser': '37.24%', 'episodesDroppedPerUser': '8.93%'}
# {'genre': 'School', 'episodesCompletedPerUser': '59.27%', 'episodesDroppedPerUser': '4.59%'}
# {'genre': 'Psychological', 'episodesCompletedPerUser': '79.61%', 'episodesDroppedPerUser': '0.8%'}
# {'genre': 'Supernatural', 'episodesCompletedPerUser': '50.13%', 'episodesDroppedPerUser': '7.37%'}
# {'genre': 'Adventure', 'episodesCompletedPerUser': '54.08%', 'episodesDroppedPerUser': '5.95%'}
# {'genre': 'Romance', 'episodesCompletedPerUser': '61.84%', 'episodesDroppedPerUser': '4.52%'}
# {'genre': 'Strategy Game', 'episodesCompletedPerUser': '53.37%', 'episodesDroppedPerUser': '4.89%'}
# {'genre': 'Game', 'episodesCompletedPerUser': '53.37%', 'episodesDroppedPerUser': '4.89%'}
# {'genre': 'Racing', 'episodesCompletedPerUser': '46.07%', 'episodesDroppedPerUser': '9.36%'}
# {'genre': 'Historical', 'episodesCompletedPerUser': '38.07%', 'episodesDroppedPerUser': '7.17%'}
# {'genre': 'Fantasy', 'episodesCompletedPerUser': '52.55%', 'episodesDroppedPerUser': '6.02%'}
# {'genre': 'Parody', 'episodesCompletedPerUser': '50.3%', 'episodesDroppedPerUser': '8.45%'}
# {'genre': 'Super Power', 'episodesCompletedPerUser': '52.6%', 'episodesDroppedPerUser': '4.87%'}
# {'genre': 'Comedy', 'episodesCompletedPerUser': '50.15%', 'episodesDroppedPerUser': '9.6%'}
# {'genre': 'Horror', 'episodesCompletedPerUser': '49.43%', 'episodesDroppedPerUser': '6.3%'}
# {'genre': 'Vampire', 'episodesCompletedPerUser': '35.43%', 'episodesDroppedPerUser': '9.11%'}
# {'genre': 'Music', 'episodesCompletedPerUser': '58.63%', 'episodesDroppedPerUser': '4.15%'}

# %%
# Query 4 Execution Function
def execute_query_8():
    start_time = time.time()
    db.anime_table.aggregate([
        {"$lookup": {
            "from": "genres_l",
            "localField": "genres_id",
            "foreignField": "genres_id",
            "as": "genres_data"}},
        {"$unwind": "$genres_data"},
        {"$lookup": {
            "from": "anime_ranking_table",
            "localField": "mal_id",
            "foreignField": "mal_id",
            "as": "ranking_data"}},
        {"$unwind": "$ranking_data"},
        {"$group": {
            "_id": "$genres_data.genres_de",
            "episodesCompletedPerUser": {
                "$avg": {
                    "$multiply": [
                        {"$divide": ["$ranking_data.statistics_completed", "$ranking_data.statistics_num_scoring_users"]},
                        100
                    ]
                }
            },
            "episodesDroppedPerUser": {
                "$avg": {
                    "$multiply": [
                        {"$divide": ["$ranking_data.statistics_dropped", "$ranking_data.statistics_num_scoring_users"]},
                        100
                    ]
                }
            }
        }},
        {"$project": {
            "_id": 0,
            "genre": "$_id",
            "episodesCompletedPerUser": {"$concat": [{"$toString": {"$round": ["$episodesCompletedPerUser", 2]}}, "%"]},
            "episodesDroppedPerUser": {"$concat": [{"$toString": {"$round": ["$episodesDroppedPerUser", 2]}}, "%"]}
        }}
    ])
    return time.time() - start_time

# Measure the execution times for query 8
execution_times_query_8 = []
for _ in range(10):
    execution_time = execute_query_8()
    execution_times_query_8.append(execution_time)

# Remove the maximum and minimum values for query 8
execution_times_query_8.remove(max(execution_times_query_8))
execution_times_query_8.remove(min(execution_times_query_8))

# Calculate the average for query 8
average_time_query_8 = sum(execution_times_query_8) / len(execution_times_query_8)
average_time_query_8 = round(average_time_query_8, 2)
print(f"Average execution time for query 8: {average_time_query_8} seconds")
# Out:
# Average execution time for query 8: 123.98 seconds

# %% [markdown]
# ## Import execution time

# %%
queries_performance_data = [
    {"Query": "Fetch popular 'Adventure' anime with a popularity over 500", "Average Execution Time (seconds)": average_time_query_1},
    {"Query": "Retrieve all 'Madhouse' studio anime titles that have finished airing", "Average Execution Time (seconds)": average_time_query_2},
    {"Query": "Retrieve and display the rank and popularity of specific anime titles", "Average Execution Time (seconds)": average_time_query_3},
    {"Query": "Check for demographic information availability for a specific anime", "Average Execution Time (seconds)": average_time_query_4},
    {"Query": "Average Popularity Of Anime Within Each Type", "Average Execution Time (seconds)": average_time_query_5},
    {"Query": "Top 5 Studios by Average Anime Rankings", "Average Execution Time (seconds)": average_time_query_6},
    {"Query": "Analyze Anime Title Popularity Over Time by Season", "Average Execution Time (seconds)": average_time_query_7},
    {"Query": "Calculate Average Episodes Stats by Anime Genre per User", "Average Execution Time (seconds)": average_time_query_8}]

# %%
queries_performance_data
# Out:
# [{'Query': "Fetch popular 'Adventure' anime with a popularity over 500",
#   'Average Execution Time (seconds)': 0.006},
#  {'Query': "Retrieve all 'Madhouse' studio anime titles that have finished airing",
#   'Average Execution Time (seconds)': 0.52},
#  {'Query': 'Retrieve and display the rank and popularity of specific anime titles',
#   'Average Execution Time (seconds)': 0.006},
#  {'Query': 'Check for demographic information availability for a specific anime',
#   'Average Execution Time (seconds)': 0.005},
#  {'Query': 'Average Popularity Of Anime Within Each Type',
#   'Average Execution Time (seconds)': 0.24},
#  {'Query': 'Top 5 Studios by Average Anime Rankings',
#   'Average Execution Time (seconds)': 0.01},
#  {'Query': 'Analyze Anime Title Popularity Over Time by Season',
#   'Average Execution Time (seconds)': 11.4},
#  {'Query': 'Calculate Average Episodes Stats by Anime Genre per User',
#   'Average Execution Time (seconds)': 123.98}]

# %%
df = pd.DataFrame(queries_performance_data)
csv_file = "queries_performance.csv"
df.to_csv(csv_file, index=False)
